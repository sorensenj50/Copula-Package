# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from scipy.special import gamma

import importlib

import bivariate, marginals, utils, tests
import visualizations as vis

importlib.reload(utils)
importlib.reload(bivariate)
importlib.reload(marginals)
importlib.reload(vis)
importlib.reload(tests)


from marginals import Normal, MarginalDist, StudentT


plt.rcParams['figure.figsize'] = (6.4, 4.8)
plt.rcParams.update({'font.size': 10})
plt.rcParams['figure.dpi'] = 75

# %%
data_path = r"/Users/johnsorensen/Documents/Data.xlsx"

close = pd.read_excel(data_path, "Close", index_col = 0, header = 0)

# %%
equity_ret = close.loc["2016":, "ES"].pct_change()
vol_ret = close.loc["2016":, "VX"].diff()

#m_equity_ret = (1 + equity_ret).resample("M").prod() - 1
#m_vol_ret = vol_ret.resample("M").sum()

equity_ret_ranks = equity_ret.rank(pct = True).dropna().values
vol_ret_ranks = vol_ret.rank(pct = True).dropna().values

# %%
print(equity_ret_ranks)
print(vol_ret_ranks)
# Out:
# [0.54124861 0.08416945 0.02396878 ... 0.2335563  0.91025641 0.31326644]
# [0.32608696 0.88684504 0.98216276 ... 0.6477146  0.22017837 0.36566332]

# %%
vis.rank_scatter(equity_ret, vol_ret, equity_ret_ranks, vol_ret_ranks)

# %%
copula1 = bivariate.Normal()
copula1.fit(equity_ret_ranks, vol_ret_ranks)

# %%
copula2 = bivariate.StudentT()
#copula2.fit(equity_ret_ranks, vol_ret_ranks)
copula2.pdf(equity_ret_ranks, vol_ret_ranks)
# Out:
# array([1.00073477, 1.00208526, 1.0211856 , 1.0144384 , 1.00267519,
#        1.01220164, 0.99944855, 1.01286347, 1.00614092, 1.00373338,
#        1.00500329, 1.01645135, 1.00620659, 1.00712269, 1.01191918,
#        1.00959269, 1.01662154, 1.01374535, 1.01628152, 1.0104252 ,
#        1.01485557, 1.01510836, 1.01317805, 1.01652337, 0.99831924,
#        0.99170195, 1.001912  , 1.01311825, 1.01538224, 1.01353402,
#        1.00903084, 1.01182722, 1.0149053 , 1.0211856 , 1.01389955,
#        1.09067814, 1.03087092, 1.01218026, 1.01564586, 1.00375512,
#        1.00706069, 0.99384432, 1.01531607, 0.99958195, 1.01286347,
#        1.01290862, 1.00394643, 1.01392058, 1.00106435, 1.07499263,
#        2.3478838 , 1.82630089, 1.00074624, 1.01061832, 1.00340508,
#        0.98533982, 0.99889821, 1.00180701, 1.29995797, 1.00881464,
#        0.9832814 , 0.97411859, 0.99665516, 0.99685188, 1.01087795,
#        1.00651833, 1.00903084, 1.00394643, 1.00067306, 1.0103835 ,
# ...

# %%
print(copula2.se)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/49/mmkh9v2n4zjdc4br5hvqsv_80000gn/T/ipykernel_47841/179587118.py in <module>
# ----> 1 print(copula2.se)
#
# AttributeError: 'StudentT' object has no attribute 'se'

# %%
print(copula2.params_dict)
# Out:
# {'df': 30, 'Q': 0}

# %%
vis.copula_contour(copula2)
# Out:
# <AxesSubplot:>
